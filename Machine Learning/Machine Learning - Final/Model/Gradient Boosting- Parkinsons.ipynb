# %%
#importing the libraries needed for ML
import pandas as pd
import numpy as np
from sklearn import preprocessing
import matplotlib.pyplot as plt 
plt.rc("font", size=14)
import seaborn as sns
sns.set(style="white")
sns.set(style="whitegrid", color_codes=True)
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler

# %%
data = pd.read_csv(r'..\Datasets\Parkinsons Train Data.csv', header = 0)
data.head()
# Out:
#    Jitter(local)  Jitter(local, absolute)  Jitter (rap)  Jitter (ppq5)  \
# 0          1.488                 0.000090         0.900          0.794
# 1          0.728                 0.000038         0.353          0.376
# 2          1.220                 0.000074         0.732          0.670
# 3          2.502                 0.000123         1.156          1.634
# 4          3.509                 0.000167         1.715          1.539
#
#    Jitter (ddp)  Shimmer (local)  Shimmer (local, db)  Shimmer (apq3)  \
# 0         2.699            8.334                0.779           4.517
# 1         1.059            5.864                0.642           2.058
# 2         2.196            8.719                0.875           4.347
# 3         3.469           13.513                1.273           5.263
# 4         5.145            9.112                1.040           3.102
#
#    Shimmer (apq5)  Shimmer (apq11)  ...  Minimum pitch  Maximum pitch  \
# 0           4.609            6.802  ...        142.229        187.576
# 1           3.180            7.194  ...        159.515        234.505
# 2           5.166            7.548  ...        146.445        211.442
# 3           8.771           16.779  ...        182.713        220.230
# 4           4.927           12.823  ...        182.821        225.162
#
#    Number of pulses  Number of periods  Mean period  \
# 0               160                159     0.006065
# 1               170                169     0.005181
# 2              1431               1427     0.006071
# 3                94                 92     0.004910
# 4               117                114     0.004757
#
#    Standard deviation of period  Fraction of locally unvoiced frames  \
# 0                      0.000416                                0.000
# 1                      0.000403                                2.247
# 2                      0.000474                               10.656
# 3                      0.000320                                0.000
# 4                      0.000380                               18.182
#
#    Number of voice breaks  Degree of voice breaks  status
# 0                       0                   0.000       1
# 1                       0                   0.000       1
# 2                       1                   0.178       1
# 3                       0                   0.000       1
# 4                       1                  13.318       1
#
# [5 rows x 27 columns]

# %%
#setting the dependent variable
y = data.iloc[:, -1].values
y
# Out:
# array([1, 1, 1, ..., 0, 0, 0], dtype=int64)

# %%
X = data.iloc[:, :-1].values
X
# Out:
# array([[1.48800e+00, 9.02130e-05, 9.00000e-01, ..., 0.00000e+00,
#         0.00000e+00, 0.00000e+00],
#        [7.28000e-01, 3.76980e-05, 3.53000e-01, ..., 2.24700e+00,
#         0.00000e+00, 0.00000e+00],
#        [1.22000e+00, 7.40410e-05, 7.32000e-01, ..., 1.06560e+01,
#         1.00000e+00, 1.78000e-01],
#        ...,
#        [2.91200e+00, 2.26205e-04, 1.14100e+00, ..., 2.00000e+01,
#         1.00000e+00, 4.57400e+00],
#        [3.78800e+00, 2.74883e-04, 1.78600e+00, ..., 1.66670e+01,
#         3.00000e+00, 1.95750e+01],
#        [1.80900e+00, 1.48510e-04, 6.80000e-01, ..., 1.81820e+01,
#         1.00000e+00, 3.38700e+00]])

# %%
from sklearn.preprocessing import StandardScaler
standard_X = StandardScaler()
standard_scaled_X = standard_X.fit_transform(X)
standard_scaled_X
# Out:
# array([[-0.67709317, -0.75525109, -0.35596897, ..., -1.32200138,
#         -0.70349085, -0.81748742],
#        [-1.10769097, -1.24846346, -0.91419898, ..., -1.21483914,
#         -0.70349085, -0.81748742],
#        [-0.82893555, -0.9071359 , -0.52741804, ..., -0.81380343,
#         -0.0848011 , -0.80575498],
#        ...,
#        [ 0.12971113,  0.52196373, -0.11002119, ..., -0.3681764 ,
#         -0.0848011 , -0.51600327],
#        [ 0.62603176,  0.97913962,  0.54822078, ..., -0.52713133,
#          1.15257839,  0.47275138],
#        [-0.49522226, -0.20773512, -0.58048561, ..., -0.45487909,
#         -0.0848011 , -0.5942415 ]])

# %%
def standardScale(X):
    X = standard_X.transform(X)
    return X

# %%
from sklearn import preprocessing
min_max_scaler = preprocessing.MinMaxScaler()
minmax_scaled_X = min_max_scaler.fit_transform(X)
minmax_scaled_X
# Out:
# array([[0.09149866, 0.108709  , 0.1053558 , ..., 0.        , 0.        ,
#         0.        ],
#        [0.03792471, 0.04051754, 0.03658537, ..., 0.02548833, 0.        ,
#         0.        ],
#        [0.0726068 , 0.08770943, 0.08423435, ..., 0.12087389, 0.08333333,
#         0.00257534],
#        ...,
#        [0.19187932, 0.28529654, 0.13565502, ..., 0.2268654 , 0.08333333,
#         0.06617764],
#        [0.25363034, 0.34850561, 0.21674629, ..., 0.18905828, 0.25      ,
#         0.28321542],
#        [0.1141266 , 0.18440848, 0.07769676, ..., 0.20624334, 0.08333333,
#         0.04900386]])

# %%
def minmaxScale(X):
    X = min_max_scaler.transform(X)
    return X

# %%
data.columns

# %%
fixed_cols = ['AC', 'NDH', 'HTM', 'Minimum pitch', 'Maximum pitch', 'Number of pulses', 'Number of periods',
              'Mean period', 'Fraction of locally unvoiced frames', 'Number of voice breaks', 'Degree of voice breaks']
jitter_cols = ['Jitter(local)', 'Jitter(local, absolute)', 'Jitter (rap)','Jitter (ppq5)', 'Jitter (ddp)']
shimmer_cols = ['Shimmer (local)', 'Shimmer (local, db)', 'Shimmer (apq3)', 'Shimmer (apq5)', 'Shimmer (apq11)',
                'Shimmer (dda)']
pitch_cols = ['Median Pitch', 'Mean Pitch']

# %%
def getGBBoosting(X, y):
    
    from sklearn.model_selection import train_test_split
    from sklearn.metrics import accuracy_score
    X_train, X_test, Y_train, Y_test = train_test_split(X, y, random_state=12, test_size = 0.2)
    # Train
    from sklearn.ensemble import GradientBoostingClassifier
    model = GradientBoostingClassifier(random_state=0)
    model.fit(X_train, Y_train)

    # Evaluate
    print("Accuracy for training set -> ", end = "")
    Y_hat = [round(yhat) for yhat in model.predict(X)]
    print(accuracy_score(y, Y_hat)) # Full set accuracy
    Y_hat = [round(yhat) for yhat in model.predict(X_test)]
    print("Accuracy for test set -> ", end = "")
    print(accuracy_score(Y_test, Y_hat)) # Test set accuracy

    #Validations
    y_pred = model.predict(X_test)

    #Confusion Matrix
    from sklearn.metrics import confusion_matrix
    cm = confusion_matrix(Y_test, y_pred) # Calulate Confusion matrix for test set.
    print(cm)

    from sklearn.model_selection import cross_val_score
    accuracies = cross_val_score(estimator = model, X = X_train, y = Y_train, cv = 10)
    print("Accuracy: {:.2f} %".format(accuracies.mean()*100))
    print("Standard Deviation: {:.2f} %".format(accuracies.std()*100))

# %%
for jitter in jitter_cols:
    for shimmer in shimmer_cols:
        for pitch in pitch_cols:
            
            fixed_cols.append(jitter)
            fixed_cols.append(shimmer)
            fixed_cols.append(pitch)
            print(fixed_cols)
            print("\n")
            print("Added columns to the dataset are:", jitter, shimmer, pitch)
            print("\n")
            X = data[fixed_cols].values
            print("---------Standard Scaled---------")
            print("\n")
            standard_X = StandardScaler()
            standard_scaled_X = standard_X.fit_transform(X)
            standard_scaled_X
            getGBBoosting(standard_scaled_X, y)
            print("\n")
            print("---------MinMax Scaled---------")
            print("\n")
            min_max_scaler = preprocessing.MinMaxScaler()
            minmax_scaled_X = min_max_scaler.fit_transform(X)
            minmax_scaled_X
            getGBBoosting(minmax_scaled_X, y)
            fixed_cols.remove(jitter)
            fixed_cols.remove(shimmer)
            fixed_cols.remove(pitch)
            print("\n")
# Out:
# ['AC', 'NDH', 'HTM', 'Minimum pitch', 'Maximum pitch', 'Number of pulses', 'Number of periods', 'Mean period', 'Fraction of locally unvoiced frames', 'Number of voice breaks', 'Degree of voice breaks', 'Jitter(local)', 'Shimmer (local)', 'Median Pitch']
#
#
# Added columns to the dataset are: Jitter(local) Shimmer (local) Median Pitch
#
#
# ---------Standard Scaled---------
#
#
# Accuracy for training set -> 0.8735521235521235
# Accuracy for test set -> 0.7211538461538461
# [[70 36]
#  [22 80]]
# Accuracy: 68.37 %
# Standard Deviation: 4.25 %
#
#
# ---------MinMax Scaled---------
#
#
# Accuracy for training set -> 0.8735521235521235
# Accuracy for test set -> 0.7211538461538461
# [[70 36]
#  [22 80]]
# Accuracy: 68.37 %
# Standard Deviation: 4.25 %
#
#
# ['AC', 'NDH', 'HTM', 'Minimum pitch', 'Maximum pitch', 'Number of pulses', 'Number of periods', 'Mean period', 'Fraction of locally unvoiced frames', 'Number of voice breaks', 'Degree of voice breaks', 'Jitter(local)', 'Shimmer (local)', 'Mean Pitch']
#
#
# Added columns to the dataset are: Jitter(local) Shimmer (local) Mean Pitch
#
#
# ---------Standard Scaled---------
#
#
# Accuracy for training set -> 0.8725868725868726
# Accuracy for test set -> 0.7019230769230769
# [[67 39]
#  [23 79]]
# Accuracy: 66.43 %
# Standard Deviation: 4.51 %
#
#
# ---------MinMax Scaled---------
#
#
# Accuracy for training set -> 0.8725868725868726
# Accuracy for test set -> 0.7019230769230769
# [[67 39]
#  [23 79]]
# Accuracy: 66.43 %
# Standard Deviation: 4.51 %
#
#
# ['AC', 'NDH', 'HTM', 'Minimum pitch', 'Maximum pitch', 'Number of pulses', 'Number of periods', 'Mean period', 'Fraction of locally unvoiced frames', 'Number of voice breaks', 'Degree of voice breaks', 'Jitter(local)', 'Shimmer (local, db)', 'Median Pitch']
#
#
# Added columns to the dataset are: Jitter(local) Shimmer (local, db) Median Pitch
#
#
# ---------Standard Scaled---------
#
#
# Accuracy for training set -> 0.8706563706563707
# Accuracy for test set -> 0.6923076923076923
# [[67 39]
#  [25 77]]
# Accuracy: 66.43 %
# Standard Deviation: 3.71 %
#
#
# ---------MinMax Scaled---------
#
#
# Accuracy for training set -> 0.8706563706563707
# Accuracy for test set -> 0.6923076923076923
# [[67 39]
#  [25 77]]
# Accuracy: 66.31 %
# Standard Deviation: 3.81 %
#
#
# ['AC', 'NDH', 'HTM', 'Minimum pitch', 'Maximum pitch', 'Number of pulses', 'Number of periods', 'Mean period', 'Fraction of locally unvoiced frames', 'Number of voice breaks', 'Degree of voice breaks', 'Jitter(local)', 'Shimmer (local, db)', 'Mean Pitch']
#
#
# Added columns to the dataset are: Jitter(local) Shimmer (local, db) Mean Pitch
#
#
# ---------Standard Scaled---------
#
#
# Accuracy for training set -> 0.861003861003861
# Accuracy for test set -> 0.7019230769230769
# [[66 40]
#  [22 80]]
# Accuracy: 66.19 %
# Standard Deviation: 3.57 %
#
#
# ---------MinMax Scaled---------
#
#
# Accuracy for training set -> 0.861003861003861
# Accuracy for test set -> 0.7019230769230769
# [[66 40]
#  [22 80]]
# Accuracy: 66.19 %
# Standard Deviation: 3.57 %
#
#
# ['AC', 'NDH', 'HTM', 'Minimum pitch', 'Maximum pitch', 'Number of pulses', 'Number of periods', 'Mean period', 'Fraction of locally unvoiced frames', 'Number of voice breaks', 'Degree of voice breaks', 'Jitter(local)', 'Shimmer (apq3)', 'Median Pitch']
#
#
# Added columns to the dataset are: Jitter(local) Shimmer (apq3) Median Pitch
#
#
# ---------Standard Scaled---------
#
#
# Accuracy for training set -> 0.8716216216216216
# Accuracy for test set -> 0.6923076923076923
# [[66 40]
#  [24 78]]
# Accuracy: 66.66 %
# Standard Deviation: 3.16 %
#
#
# ---------MinMax Scaled---------
#
#
# Accuracy for training set -> 0.8716216216216216
# Accuracy for test set -> 0.6923076923076923
# [[66 40]
#  [24 78]]
# Accuracy: 66.54 %
# Standard Deviation: 3.30 %
#
#
# ['AC', 'NDH', 'HTM', 'Minimum pitch', 'Maximum pitch', 'Number of pulses', 'Number of periods', 'Mean period', 'Fraction of locally unvoiced frames', 'Number of voice breaks', 'Degree of voice breaks', 'Jitter(local)', 'Shimmer (apq3)', 'Mean Pitch']
#
#
# Added columns to the dataset are: Jitter(local) Shimmer (apq3) Mean Pitch
#
#
# ---------Standard Scaled---------
#
#
# Accuracy for training set -> 0.8571428571428571
# Accuracy for test set -> 0.6778846153846154
# [[65 41]
#  [26 76]]
# Accuracy: 65.34 %
# Standard Deviation: 4.89 %
#
#
# ---------MinMax Scaled---------
#
#
# Accuracy for training set -> 0.8571428571428571
# Accuracy for test set -> 0.6778846153846154
# [[65 41]
#  [26 76]]
# Accuracy: 65.34 %
# Standard Deviation: 4.89 %
#
#
# ['AC', 'NDH', 'HTM', 'Minimum pitch', 'Maximum pitch', 'Number of pulses', 'Number of periods', 'Mean period', 'Fraction of locally unvoiced frames', 'Number of voice breaks', 'Degree of voice breaks', 'Jitter(local)', 'Shimmer (apq5)', 'Median Pitch']
#
#
# Added columns to the dataset are: Jitter(local) Shimmer (apq5) Median Pitch
#
#
# ---------Standard Scaled---------
#
#
# Accuracy for training set -> 0.8764478764478765
# Accuracy for test set -> 0.6923076923076923
# [[70 36]
#  [28 74]]
# Accuracy: 68.60 %
# Standard Deviation: 3.34 %
#
#
# ---------MinMax Scaled---------
#
#
# Accuracy for training set -> 0.8764478764478765
# Accuracy for test set -> 0.6923076923076923
# [[70 36]
#  [28 74]]
# Accuracy: 68.60 %
# Standard Deviation: 3.34 %
#
#
# ['AC', 'NDH', 'HTM', 'Minimum pitch', 'Maximum pitch', 'Number of pulses', 'Number of periods', 'Mean period', 'Fraction of locally unvoiced frames', 'Number of voice breaks', 'Degree of voice breaks', 'Jitter(local)', 'Shimmer (apq5)', 'Mean Pitch']
#
#
# Added columns to the dataset are: Jitter(local) Shimmer (apq5) Mean Pitch
#
#
# ---------Standard Scaled---------
#
#
# Accuracy for training set -> 0.8774131274131274
# Accuracy for test set -> 0.6923076923076923
# [[70 36]
#  [28 74]]
# Accuracy: 67.27 %
# Standard Deviation: 5.22 %
#
#
# ---------MinMax Scaled---------
#
#
# Accuracy for training set -> 0.8774131274131274
# Accuracy for test set -> 0.6923076923076923
# [[70 36]
#  [28 74]]
# Accuracy: 67.27 %
# Standard Deviation: 5.22 %
#
#
# ['AC', 'NDH', 'HTM', 'Minimum pitch', 'Maximum pitch', 'Number of pulses', 'Number of periods', 'Mean period', 'Fraction of locally unvoiced frames', 'Number of voice breaks', 'Degree of voice breaks', 'Jitter(local)', 'Shimmer (apq11)', 'Median Pitch']
#
#
# Added columns to the dataset are: Jitter(local) Shimmer (apq11) Median Pitch
#
#
# ---------Standard Scaled---------
#
#
# Accuracy for training set -> 0.8754826254826255
# Accuracy for test set -> 0.7451923076923077
# [[76 30]
#  [23 79]]
# Accuracy: 67.63 %
# Standard Deviation: 4.48 %
#
#
# ---------MinMax Scaled---------
#
#
# Accuracy for training set -> 0.8754826254826255
# Accuracy for test set -> 0.7451923076923077
# [[76 30]
#  [23 79]]
# Accuracy: 67.63 %
# Standard Deviation: 4.48 %
#
#
# ['AC', 'NDH', 'HTM', 'Minimum pitch', 'Maximum pitch', 'Number of pulses', 'Number of periods', 'Mean period', 'Fraction of locally unvoiced frames', 'Number of voice breaks', 'Degree of voice breaks', 'Jitter(local)', 'Shimmer (apq11)', 'Mean Pitch']
#
#
# Added columns to the dataset are: Jitter(local) Shimmer (apq11) Mean Pitch
#
#
# ---------Standard Scaled---------
#
#
# Accuracy for training set -> 0.8716216216216216
# Accuracy for test set -> 0.7067307692307693
# [[68 38]
#  [23 79]]
# Accuracy: 66.80 %
# Standard Deviation: 6.45 %
#
#
# ---------MinMax Scaled---------
#
#
# Accuracy for training set -> 0.8716216216216216
# Accuracy for test set -> 0.7067307692307693
# [[68 38]
#  [23 79]]
# Accuracy: 66.80 %
# Standard Deviation: 6.45 %
#
#
# ['AC', 'NDH', 'HTM', 'Minimum pitch', 'Maximum pitch', 'Number of pulses', 'Number of periods', 'Mean period', 'Fraction of locally unvoiced frames', 'Number of voice breaks', 'Degree of voice breaks', 'Jitter(local)', 'Shimmer (dda)', 'Median Pitch']
#
#
# Added columns to the dataset are: Jitter(local) Shimmer (dda) Median Pitch
#
#
# ---------Standard Scaled---------
#
#
# Accuracy for training set -> 0.8716216216216216
# Accuracy for test set -> 0.6923076923076923
# [[66 40]
#  [24 78]]
# Accuracy: 66.66 %
# Standard Deviation: 3.16 %
#
#
# ---------MinMax Scaled---------
#
#
# Accuracy for training set -> 0.8716216216216216
# Accuracy for test set -> 0.6923076923076923
# [[66 40]
#  [24 78]]
# Accuracy: 66.54 %
# Standard Deviation: 3.30 %
#
#
# ['AC', 'NDH', 'HTM', 'Minimum pitch', 'Maximum pitch', 'Number of pulses', 'Number of periods', 'Mean period', 'Fraction of locally unvoiced frames', 'Number of voice breaks', 'Degree of voice breaks', 'Jitter(local)', 'Shimmer (dda)', 'Mean Pitch']
#
#
# Added columns to the dataset are: Jitter(local) Shimmer (dda) Mean Pitch
#
#
# ---------Standard Scaled---------
# Accuracy for training set -> 0.8571428571428571
# Accuracy for test set -> 0.6778846153846154
# [[65 41]
#  [26 76]]
# Accuracy: 65.34 %
# Standard Deviation: 4.89 %
#
#
# ---------MinMax Scaled---------
#
#
# Accuracy for training set -> 0.8571428571428571
# Accuracy for test set -> 0.6778846153846154
# [[65 41]
#  [26 76]]
# Accuracy: 65.34 %
# Standard Deviation: 4.89 %
#
#
# ['AC', 'NDH', 'HTM', 'Minimum pitch', 'Maximum pitch', 'Number of pulses', 'Number of periods', 'Mean period', 'Fraction of locally unvoiced frames', 'Number of voice breaks', 'Degree of voice breaks', 'Jitter(local, absolute)', 'Shimmer (local)', 'Median Pitch']
#
#
# Added columns to the dataset are: Jitter(local, absolute) Shimmer (local) Median Pitch
#
#
# ---------Standard Scaled---------
#
#
# Accuracy for training set -> 0.8803088803088803
# Accuracy for test set -> 0.7019230769230769
# [[68 38]
#  [24 78]]
# Accuracy: 67.02 %
# Standard Deviation: 4.83 %
#
#
# ---------MinMax Scaled---------
#
#
# Accuracy for training set -> 0.8803088803088803
# Accuracy for test set -> 0.7019230769230769
# [[68 38]
#  [24 78]]
# Accuracy: 66.90 %
# Standard Deviation: 4.80 %
#
#
# ['AC', 'NDH', 'HTM', 'Minimum pitch', 'Maximum pitch', 'Number of pulses', 'Number of periods', 'Mean period', 'Fraction of locally unvoiced frames', 'Number of voice breaks', 'Degree of voice breaks', 'Jitter(local, absolute)', 'Shimmer (local)', 'Mean Pitch']
#
#
# Added columns to the dataset are: Jitter(local, absolute) Shimmer (local) Mean Pitch
#
#
# ---------Standard Scaled---------
#
#
# Accuracy for training set -> 0.8638996138996139
# Accuracy for test set -> 0.6442307692307693
# [[63 43]
#  [31 71]]
# Accuracy: 66.55 %
# Standard Deviation: 3.57 %
#
#
# ---------MinMax Scaled---------
#
#
# Accuracy for training set -> 0.8638996138996139
# Accuracy for test set -> 0.6442307692307693
# [[63 43]
#  [31 71]]
# Accuracy: 66.55 %
# Standard Deviation: 3.57 %
#
#
# ['AC', 'NDH', 'HTM', 'Minimum pitch', 'Maximum pitch', 'Number of pulses', 'Number of periods', 'Mean period', 'Fraction of locally unvoiced frames', 'Number of voice breaks', 'Degree of voice breaks', 'Jitter(local, absolute)', 'Shimmer (local, db)', 'Median Pitch']
#
#
# Added columns to the dataset are: Jitter(local, absolute) Shimmer (local, db) Median Pitch
#
#
# ---------Standard Scaled---------
#
#
# Accuracy for training set -> 0.8677606177606177
# Accuracy for test set -> 0.6971153846153846
# [[69 37]
#  [26 76]]
# Accuracy: 68.83 %
# Standard Deviation: 3.77 %
#
#
# ---------MinMax Scaled---------
#
#
# Accuracy for training set -> 0.8677606177606177
# Accuracy for test set -> 0.6971153846153846
# [[69 37]
#  [26 76]]
# Accuracy: 68.71 %
# Standard Deviation: 3.76 %
#
#
# ['AC', 'NDH', 'HTM', 'Minimum pitch', 'Maximum pitch', 'Number of pulses', 'Number of periods', 'Mean period', 'Fraction of locally unvoiced frames', 'Number of voice breaks', 'Degree of voice breaks', 'Jitter(local, absolute)', 'Shimmer (local, db)', 'Mean Pitch']
#
#
# Added columns to the dataset are: Jitter(local, absolute) Shimmer (local, db) Mean Pitch
#
#
# ---------Standard Scaled---------
#
#
# Accuracy for training set -> 0.8783783783783784
# Accuracy for test set -> 0.6923076923076923
# [[66 40]
#  [24 78]]
# Accuracy: 65.94 %
# Standard Deviation: 4.39 %
#
#
# ---------MinMax Scaled---------
#
#
# Accuracy for training set -> 0.8783783783783784
# Accuracy for test set -> 0.6923076923076923
# [[66 40]
#  [24 78]]
# Accuracy: 65.94 %
# Standard Deviation: 4.39 %
#
#
# ['AC', 'NDH', 'HTM', 'Minimum pitch', 'Maximum pitch', 'Number of pulses', 'Number of periods', 'Mean period', 'Fraction of locally unvoiced frames', 'Number of voice breaks', 'Degree of voice breaks', 'Jitter(local, absolute)', 'Shimmer (apq3)', 'Median Pitch']
#
#
# Added columns to the dataset are: Jitter(local, absolute) Shimmer (apq3) Median Pitch
#
#
# ---------Standard Scaled---------
#
#
# Accuracy for training set -> 0.8648648648648649
# Accuracy for test set -> 0.6730769230769231
# [[66 40]
#  [28 74]]
# Accuracy: 65.58 %
# Standard Deviation: 3.25 %
#
#
# ---------MinMax Scaled---------
#
#
# Accuracy for training set -> 0.8648648648648649
# Accuracy for test set -> 0.6730769230769231
# [[66 40]
#  [28 74]]
# Accuracy: 65.58 %
# Standard Deviation: 3.25 %
#
#
# ['AC', 'NDH', 'HTM', 'Minimum pitch', 'Maximum pitch', 'Number of pulses', 'Number of periods', 'Mean period', 'Fraction of locally unvoiced frames', 'Number of voice breaks', 'Degree of voice breaks', 'Jitter(local, absolute)', 'Shimmer (apq3)', 'Mean Pitch']
#
#
# Added columns to the dataset are: Jitter(local, absolute) Shimmer (apq3) Mean Pitch
#
#
# ---------Standard Scaled---------
#
#
# Accuracy for training set -> 0.8532818532818532
# Accuracy for test set -> 0.6490384615384616
# [[64 42]
#  [31 71]]
# Accuracy: 66.06 %
# Standard Deviation: 3.65 %
#
#
# ---------MinMax Scaled---------
#
#
# Accuracy for training set -> 0.8532818532818532
# Accuracy for test set -> 0.6490384615384616
# [[64 42]
#  [31 71]]
# Accuracy: 66.06 %
# Standard Deviation: 3.65 %
#
#
# ['AC', 'NDH', 'HTM', 'Minimum pitch', 'Maximum pitch', 'Number of pulses', 'Number of periods', 'Mean period', 'Fraction of locally unvoiced frames', 'Number of voice breaks', 'Degree of voice breaks', 'Jitter(local, absolute)', 'Shimmer (apq5)', 'Median Pitch']
#
#
# Added columns to the dataset are: Jitter(local, absolute) Shimmer (apq5) Median Pitch
#
#
# ---------Standard Scaled---------
#
#
# Accuracy for training set -> 0.8822393822393823
# Accuracy for test set -> 0.7211538461538461
# [[74 32]
#  [26 76]]
# Accuracy: 67.87 %
# Standard Deviation: 4.27 %
#
#
# ---------MinMax Scaled---------
#
#
# Accuracy for training set -> 0.8822393822393823
# Accuracy for test set -> 0.7211538461538461
# [[74 32]
#  [26 76]]
# Accuracy: 67.87 %
# Standard Deviation: 4.27 %
#
#
# ['AC', 'NDH', 'HTM', 'Minimum pitch', 'Maximum pitch', 'Number of pulses', 'Number of periods', 'Mean period', 'Fraction of locally unvoiced frames', 'Number of voice breaks', 'Degree of voice breaks', 'Jitter(local, absolute)', 'Shimmer (apq5)', 'Mean Pitch']
#
#
# Added columns to the dataset are: Jitter(local, absolute) Shimmer (apq5) Mean Pitch
#
#
# ---------Standard Scaled---------
#
#
# Accuracy for training set -> 0.8764478764478765
# Accuracy for test set -> 0.6971153846153846
# [[69 37]
#  [26 76]]
# Accuracy: 66.66 %
# Standard Deviation: 5.90 %
#
#
# ---------MinMax Scaled---------
#
#
# Accuracy for training set -> 0.8754826254826255
# Accuracy for test set -> 0.6923076923076923
# [[69 37]
#  [27 75]]
# Accuracy: 66.66 %
# Standard Deviation: 5.90 %
#
#
# ['AC', 'NDH', 'HTM', 'Minimum pitch', 'Maximum pitch', 'Number of pulses', 'Number of periods', 'Mean period', 'Fraction of locally unvoiced frames', 'Number of voice breaks', 'Degree of voice breaks', 'Jitter(local, absolute)', 'Shimmer (apq11)', 'Median Pitch']
#
#
# Added columns to the dataset are: Jitter(local, absolute) Shimmer (apq11) Median Pitch
#
#
# ---------Standard Scaled---------
#
#
# Accuracy for training set -> 0.8812741312741312
# Accuracy for test set -> 0.7115384615384616
# [[72 34]
#  [26 76]]
# Accuracy: 68.22 %
# Standard Deviation: 4.93 %
#
#
# ---------MinMax Scaled---------
#
#
# Accuracy for training set -> 0.8812741312741312
# Accuracy for test set -> 0.7115384615384616
# [[72 34]
#  [26 76]]
# Accuracy: 68.22 %
# Standard Deviation: 4.93 %
#
#
# ['AC', 'NDH', 'HTM', 'Minimum pitch', 'Maximum pitch', 'Number of pulses', 'Number of periods', 'Mean period', 'Fraction of locally unvoiced frames', 'Number of voice breaks', 'Degree of voice breaks', 'Jitter(local, absolute)', 'Shimmer (apq11)', 'Mean Pitch']
#
#
# Added columns to the dataset are: Jitter(local, absolute) Shimmer (apq11) Mean Pitch
#
#
# ---------Standard Scaled---------
#
#
# Accuracy for training set -> 0.8706563706563707
# Accuracy for test set -> 0.6923076923076923
# [[73 33]
#  [31 71]]
# Accuracy: 66.55 %
# Standard Deviation: 4.76 %
#
#
# ---------MinMax Scaled---------
#
#
# Accuracy for training set -> 0.8706563706563707
# Accuracy for test set -> 0.6923076923076923
# [[73 33]
#  [31 71]]
# Accuracy: 66.67 %
# Standard Deviation: 4.85 %
#
#
# ['AC', 'NDH', 'HTM', 'Minimum pitch', 'Maximum pitch', 'Number of pulses', 'Number of periods', 'Mean period', 'Fraction of locally unvoiced frames', 'Number of voice breaks', 'Degree of voice breaks', 'Jitter(local, absolute)', 'Shimmer (dda)', 'Median Pitch']
#
#
# Added columns to the dataset are: Jitter(local, absolute) Shimmer (dda) Median Pitch
#
#
# ---------Standard Scaled---------
#
#
# Accuracy for training set -> 0.8648648648648649
# Accuracy for test set -> 0.6730769230769231
# [[66 40]
#  [28 74]]
# Accuracy: 65.58 %
# Standard Deviation: 3.25 %
#
#
# ---------MinMax Scaled---------
#
#
# Accuracy for training set -> 0.8648648648648649
# Accuracy for test set -> 0.6730769230769231
# [[66 40]
#  [28 74]]
# Accuracy: 65.58 %
# Standard Deviation: 3.25 %
#
#
# ['AC', 'NDH', 'HTM', 'Minimum pitch', 'Maximum pitch', 'Number of pulses', 'Number of periods', 'Mean period', 'Fraction of locally unvoiced frames', 'Number of voice breaks', 'Degree of voice breaks', 'Jitter(local, absolute)', 'Shimmer (dda)', 'Mean Pitch']
#
#
# Added columns to the dataset are: Jitter(local, absolute) Shimmer (dda) Mean Pitch
#
#
# ---------Standard Scaled---------
#
#
# Accuracy for training set -> 0.8532818532818532
# Accuracy for test set -> 0.6490384615384616
# [[64 42]
#  [31 71]]
# Accuracy: 66.06 %
# Standard Deviation: 3.65 %
#
#
# ---------MinMax Scaled---------
#
#
# Accuracy for training set -> 0.8532818532818532
# Accuracy for test set -> 0.6490384615384616
# [[64 42]
#  [31 71]]
# Accuracy: 66.06 %
# Standard Deviation: 3.65 %
#
#
# ['AC', 'NDH', 'HTM', 'Minimum pitch', 'Maximum pitch', 'Number of pulses', 'Number of periods', 'Mean period', 'Fraction of locally unvoiced frames', 'Number of voice breaks', 'Degree of voice breaks', 'Jitter (rap)', 'Shimmer (local)', 'Median Pitch']
#
#
# Added columns to the dataset are: Jitter (rap) Shimmer (local) Median Pitch
#
#
# ---------Standard Scaled---------
#
#
# Accuracy for training set -> 0.8677606177606177
# Accuracy for test set -> 0.6586538461538461
# [[62 44]
#  [27 75]]
# Accuracy: 70.04 %
# Standard Deviation: 3.74 %
#
#
# ---------MinMax Scaled---------
#
#
# Accuracy for training set -> 0.8677606177606177
# Accuracy for test set -> 0.6586538461538461
# [[62 44]
#  [27 75]]
# Accuracy: 69.92 %
# Standard Deviation: 4.01 %
#
#
# ['AC', 'NDH', 'HTM', 'Minimum pitch', 'Maximum pitch', 'Number of pulses', 'Number of periods', 'Mean period', 'Fraction of locally unvoiced frames', 'Number of voice breaks', 'Degree of voice breaks', 'Jitter (rap)', 'Shimmer (local)', 'Mean Pitch']
#
#
# Added columns to the dataset are: Jitter (rap) Shimmer (local) Mean Pitch
#
#
# ---------Standard Scaled---------
#
#
# Accuracy for training set -> 0.86003861003861
# Accuracy for test set -> 0.6682692307692307
# [[64 42]
#  [27 75]]
# Accuracy: 67.75 %
# Standard Deviation: 3.38 %
#
#
# ---------MinMax Scaled---------
#
#
# Accuracy for training set -> 0.86003861003861
# Accuracy for test set -> 0.6682692307692307
# [[64 42]
#  [27 75]]
# Accuracy: 67.75 %
# Standard Deviation: 3.38 %
#
#
# ['AC', 'NDH', 'HTM', 'Minimum pitch', 'Maximum pitch', 'Number of pulses', 'Number of periods', 'Mean period', 'Fraction of locally unvoiced frames', 'Number of voice breaks', 'Degree of voice breaks', 'Jitter (rap)', 'Shimmer (local, db)', 'Median Pitch']
#
#
# Added columns to the dataset are: Jitter (rap) Shimmer (local, db) Median Pitch
#
#
# ---------Standard Scaled---------
#
#
# Accuracy for training set -> 0.8716216216216216
# Accuracy for test set -> 0.6923076923076923
# [[69 37]
#  [27 75]]
# Accuracy: 66.78 %
# Standard Deviation: 4.43 %
#
#
# ---------MinMax Scaled---------
#
#
# Accuracy for training set -> 0.8716216216216216
# Accuracy for test set -> 0.6923076923076923
# [[69 37]
#  [27 75]]
# Accuracy: 66.66 %
# Standard Deviation: 4.57 %
#
#
# ['AC', 'NDH', 'HTM', 'Minimum pitch', 'Maximum pitch', 'Number of pulses', 'Number of periods', 'Mean period', 'Fraction of locally unvoiced frames', 'Number of voice breaks', 'Degree of voice breaks', 'Jitter (rap)', 'Shimmer (local, db)', 'Mean Pitch']
#
#
# Added columns to the dataset are: Jitter (rap) Shimmer (local, db) Mean Pitch
#
#
# ---------Standard Scaled---------
#
#
# Accuracy for training set -> 0.8571428571428571
# Accuracy for test set -> 0.6826923076923077
# [[64 42]
#  [24 78]]
# Accuracy: 67.39 %
# Standard Deviation: 4.35 %
#
#
# ---------MinMax Scaled---------
#
#
# Accuracy for training set -> 0.8571428571428571
# Accuracy for test set -> 0.6826923076923077
# [[64 42]
#  [24 78]]
# Accuracy: 67.27 %
# Standard Deviation: 4.23 %
#
#
# ['AC', 'NDH', 'HTM', 'Minimum pitch', 'Maximum pitch', 'Number of pulses', 'Number of periods', 'Mean period', 'Fraction of locally unvoiced frames', 'Number of voice breaks', 'Degree of voice breaks', 'Jitter (rap)', 'Shimmer (apq3)', 'Median Pitch']
#
#
# Added columns to the dataset are: Jitter (rap) Shimmer (apq3) Median Pitch
#
#
# ---------Standard Scaled---------
#
#
# Accuracy for training set -> 0.8532818532818532
# Accuracy for test set -> 0.6586538461538461
# [[66 40]
#  [31 71]]
# Accuracy: 66.29 %
# Standard Deviation: 4.60 %
#
#
# ---------MinMax Scaled---------
#
#
# Accuracy for training set -> 0.8532818532818532
# Accuracy for test set -> 0.6586538461538461
# [[66 40]
#  [31 71]]
# Accuracy: 66.29 %
# Standard Deviation: 4.60 %
#
#
# ['AC', 'NDH', 'HTM', 'Minimum pitch', 'Maximum pitch', 'Number of pulses', 'Number of periods', 'Mean period', 'Fraction of locally unvoiced frames', 'Number of voice breaks', 'Degree of voice breaks', 'Jitter (rap)', 'Shimmer (apq3)', 'Mean Pitch']
#
#
# Added columns to the dataset are: Jitter (rap) Shimmer (apq3) Mean Pitch
#
#
# ---------Standard Scaled---------
#
#
# Accuracy for training set -> 0.8532818532818532
# Accuracy for test set -> 0.6586538461538461
# [[64 42]
#  [29 73]]
# Accuracy: 65.69 %
# Standard Deviation: 4.43 %
#
#
# ---------MinMax Scaled---------
#
#
# Accuracy for training set -> 0.8532818532818532
# Accuracy for test set -> 0.6586538461538461
# [[64 42]
#  [29 73]]
# Accuracy: 65.69 %
# Standard Deviation: 4.43 %
#
#
# ['AC', 'NDH', 'HTM', 'Minimum pitch', 'Maximum pitch', 'Number of pulses', 'Number of periods', 'Mean period', 'Fraction of locally unvoiced frames', 'Number of voice breaks', 'Degree of voice breaks', 'Jitter (rap)', 'Shimmer (apq5)', 'Median Pitch']
#
#
# Added columns to the dataset are: Jitter (rap) Shimmer (apq5) Median Pitch
#
#
# ---------Standard Scaled---------
#
#
# Accuracy for training set -> 0.8648648648648649
# Accuracy for test set -> 0.6682692307692307
# [[69 37]
#  [32 70]]
# Accuracy: 67.38 %
# Standard Deviation: 3.68 %
#
#
# ---------MinMax Scaled---------
#
#
# Accuracy for training set -> 0.8648648648648649
# Accuracy for test set -> 0.6682692307692307
# [[69 37]
#  [32 70]]
# Accuracy: 67.38 %
# Standard Deviation: 3.68 %
#
#
# ['AC', 'NDH', 'HTM', 'Minimum pitch', 'Maximum pitch', 'Number of pulses', 'Number of periods', 'Mean period', 'Fraction of locally unvoiced frames', 'Number of voice breaks', 'Degree of voice breaks', 'Jitter (rap)', 'Shimmer (apq5)', 'Mean Pitch']
#
#
# Added columns to the dataset are: Jitter (rap) Shimmer (apq5) Mean Pitch
#
#
# ---------Standard Scaled---------
#
#
# Accuracy for training set -> 0.8638996138996139
# Accuracy for test set -> 0.6682692307692307
# [[66 40]
#  [29 73]]
# Accuracy: 67.87 %
# Standard Deviation: 4.98 %
#
#
# ---------MinMax Scaled---------
#
#
# Accuracy for training set -> 0.8638996138996139
# Accuracy for test set -> 0.6682692307692307
# [[66 40]
#  [29 73]]
# Accuracy: 67.87 %
# Standard Deviation: 4.98 %
#
#
# ['AC', 'NDH', 'HTM', 'Minimum pitch', 'Maximum pitch', 'Number of pulses', 'Number of periods', 'Mean period', 'Fraction of locally unvoiced frames', 'Number of voice breaks', 'Degree of voice breaks', 'Jitter (rap)', 'Shimmer (apq11)', 'Median Pitch']
#
#
# Added columns to the dataset are: Jitter (rap) Shimmer (apq11) Median Pitch
#
#
# ---------Standard Scaled---------
#
#
# Accuracy for training set -> 0.8793436293436293
# Accuracy for test set -> 0.6971153846153846
# [[71 35]
#  [28 74]]
# Accuracy: 68.22 %
# Standard Deviation: 4.59 %
#
#
# ---------MinMax Scaled---------
#
#
# Accuracy for training set -> 0.8803088803088803
# Accuracy for test set -> 0.7019230769230769
# [[72 34]
#  [28 74]]
# Accuracy: 68.22 %
# Standard Deviation: 4.59 %
#
#
# ['AC', 'NDH', 'HTM', 'Minimum pitch', 'Maximum pitch', 'Number of pulses', 'Number of periods', 'Mean period', 'Fraction of locally unvoiced frames', 'Number of voice breaks', 'Degree of voice breaks', 'Jitter (rap)', 'Shimmer (apq11)', 'Mean Pitch']
#
#
# Added columns to the dataset are: Jitter (rap) Shimmer (apq11) Mean Pitch
#
#
# ---------Standard Scaled---------
#
#
# Accuracy for training set -> 0.8638996138996139
# Accuracy for test set -> 0.6826923076923077
# [[71 35]
#  [31 71]]
# Accuracy: 67.27 %
# Standard Deviation: 4.72 %
#
#
# ---------MinMax Scaled---------
#
#
# Accuracy for training set -> 0.8638996138996139
# Accuracy for test set -> 0.6826923076923077
# [[71 35]
#  [31 71]]
# Accuracy: 67.27 %
# Standard Deviation: 4.72 %
#
#
# ['AC', 'NDH', 'HTM', 'Minimum pitch', 'Maximum pitch', 'Number of pulses', 'Number of periods', 'Mean period', 'Fraction of locally unvoiced frames', 'Number of voice breaks', 'Degree of voice breaks', 'Jitter (rap)', 'Shimmer (dda)', 'Median Pitch']
#
#
# Added columns to the dataset are: Jitter (rap) Shimmer (dda) Median Pitch
#
#
# ---------Standard Scaled---------
# Accuracy for training set -> 0.8532818532818532
# Accuracy for test set -> 0.6586538461538461
# [[66 40]
#  [31 71]]
# Accuracy: 66.29 %
# Standard Deviation: 4.60 %
#
#
# ---------MinMax Scaled---------
#
#
# Accuracy for training set -> 0.8532818532818532
# Accuracy for test set -> 0.6586538461538461
# [[66 40]
#  [31 71]]
# Accuracy: 66.29 %
# Standard Deviation: 4.60 %
#
#
# ['AC', 'NDH', 'HTM', 'Minimum pitch', 'Maximum pitch', 'Number of pulses', 'Number of periods', 'Mean period', 'Fraction of locally unvoiced frames', 'Number of voice breaks', 'Degree of voice breaks', 'Jitter (rap)', 'Shimmer (dda)', 'Mean Pitch']
#
#
# Added columns to the dataset are: Jitter (rap) Shimmer (dda) Mean Pitch
#
#
# ---------Standard Scaled---------
#
#
# Accuracy for training set -> 0.8532818532818532
# Accuracy for test set -> 0.6586538461538461
# [[64 42]
#  [29 73]]
# Accuracy: 65.69 %
# Standard Deviation: 4.43 %
#
#
# ---------MinMax Scaled---------
#
#
# Accuracy for training set -> 0.8532818532818532
# Accuracy for test set -> 0.6586538461538461
# [[64 42]
#  [29 73]]
# Accuracy: 65.69 %
# Standard Deviation: 4.43 %
#
#
# ['AC', 'NDH', 'HTM', 'Minimum pitch', 'Maximum pitch', 'Number of pulses', 'Number of periods', 'Mean period', 'Fraction of locally unvoiced frames', 'Number of voice breaks', 'Degree of voice breaks', 'Jitter (ppq5)', 'Shimmer (local)', 'Median Pitch']
#
#
# Added columns to the dataset are: Jitter (ppq5) Shimmer (local) Median Pitch
#
#
# ---------Standard Scaled---------
#
#
# Accuracy for training set -> 0.8658301158301158
# Accuracy for test set -> 0.7019230769230769
# [[68 38]
#  [24 78]]
# Accuracy: 67.86 %
# Standard Deviation: 6.59 %
#
#
# ---------MinMax Scaled---------
#
#
# Accuracy for training set -> 0.8658301158301158
# Accuracy for test set -> 0.7019230769230769
# [[68 38]
#  [24 78]]
# Accuracy: 67.74 %
# Standard Deviation: 6.79 %
#
#
# ['AC', 'NDH', 'HTM', 'Minimum pitch', 'Maximum pitch', 'Number of pulses', 'Number of periods', 'Mean period', 'Fraction of locally unvoiced frames', 'Number of voice breaks', 'Degree of voice breaks', 'Jitter (ppq5)', 'Shimmer (local)', 'Mean Pitch']
#
#
# Added columns to the dataset are: Jitter (ppq5) Shimmer (local) Mean Pitch
#
#
# ---------Standard Scaled---------
#
#
# Accuracy for training set -> 0.8658301158301158
# Accuracy for test set -> 0.6875
# [[68 38]
#  [27 75]]
# Accuracy: 68.12 %
# Standard Deviation: 5.69 %
#
#
# ---------MinMax Scaled---------
#
#
# Accuracy for training set -> 0.8658301158301158
# Accuracy for test set -> 0.6875
# [[68 38]
#  [27 75]]
# Accuracy: 68.00 %
# Standard Deviation: 5.78 %
#
#
# ['AC', 'NDH', 'HTM', 'Minimum pitch', 'Maximum pitch', 'Number of pulses', 'Number of periods', 'Mean period', 'Fraction of locally unvoiced frames', 'Number of voice breaks', 'Degree of voice breaks', 'Jitter (ppq5)', 'Shimmer (local, db)', 'Median Pitch']
#
#
# Added columns to the dataset are: Jitter (ppq5) Shimmer (local, db) Median Pitch
#
#
# ---------Standard Scaled---------
#
#
# Accuracy for training set -> 0.8716216216216216
# Accuracy for test set -> 0.7115384615384616
# [[69 37]
#  [23 79]]
# Accuracy: 66.30 %
# Standard Deviation: 5.42 %
#
#
# ---------MinMax Scaled---------
#
#
# Accuracy for training set -> 0.8716216216216216
# Accuracy for test set -> 0.7115384615384616
# [[69 37]
#  [23 79]]
# Accuracy: 66.18 %
# Standard Deviation: 5.43 %
#
#
# ['AC', 'NDH', 'HTM', 'Minimum pitch', 'Maximum pitch', 'Number of pulses', 'Number of periods', 'Mean period', 'Fraction of locally unvoiced frames', 'Number of voice breaks', 'Degree of voice breaks', 'Jitter (ppq5)', 'Shimmer (local, db)', 'Mean Pitch']
#
#
# Added columns to the dataset are: Jitter (ppq5) Shimmer (local, db) Mean Pitch
#
#
# ---------Standard Scaled---------
#
#
# Accuracy for training set -> 0.8513513513513513
# Accuracy for test set -> 0.6682692307692307
# [[63 43]
#  [26 76]]
# Accuracy: 65.69 %
# Standard Deviation: 5.94 %
#
#
# ---------MinMax Scaled---------
#
#
# Accuracy for training set -> 0.8513513513513513
# Accuracy for test set -> 0.6682692307692307
# [[63 43]
#  [26 76]]
# Accuracy: 65.69 %
# Standard Deviation: 5.94 %
#
#
# ['AC', 'NDH', 'HTM', 'Minimum pitch', 'Maximum pitch', 'Number of pulses', 'Number of periods', 'Mean period', 'Fraction of locally unvoiced frames', 'Number of voice breaks', 'Degree of voice breaks', 'Jitter (ppq5)', 'Shimmer (apq3)', 'Median Pitch']
#
#
# Added columns to the dataset are: Jitter (ppq5) Shimmer (apq3) Median Pitch
#
#
# ---------Standard Scaled---------
#
#
# Accuracy for training set -> 0.8571428571428571
# Accuracy for test set -> 0.6778846153846154
# [[67 39]
#  [28 74]]
# Accuracy: 67.01 %
# Standard Deviation: 6.09 %
#
#
# ---------MinMax Scaled---------
#
#
# Accuracy for training set -> 0.8571428571428571
# Accuracy for test set -> 0.6778846153846154
# [[67 39]
#  [28 74]]
# Accuracy: 67.01 %
# Standard Deviation: 6.09 %
#
#
# ['AC', 'NDH', 'HTM', 'Minimum pitch', 'Maximum pitch', 'Number of pulses', 'Number of periods', 'Mean period', 'Fraction of locally unvoiced frames', 'Number of voice breaks', 'Degree of voice breaks', 'Jitter (ppq5)', 'Shimmer (apq3)', 'Mean Pitch']
#
#
# Added columns to the dataset are: Jitter (ppq5) Shimmer (apq3) Mean Pitch
#
#
# ---------Standard Scaled---------
#
#
# Accuracy for training set -> 0.8581081081081081
# Accuracy for test set -> 0.6682692307692307
# [[65 41]
#  [28 74]]
# Accuracy: 66.06 %
# Standard Deviation: 4.11 %
#
#
# ---------MinMax Scaled---------
#
#
# Accuracy for training set -> 0.8581081081081081
# Accuracy for test set -> 0.6682692307692307
# [[65 41]
#  [28 74]]
# Accuracy: 66.06 %
# Standard Deviation: 4.11 %
#
#
# ['AC', 'NDH', 'HTM', 'Minimum pitch', 'Maximum pitch', 'Number of pulses', 'Number of periods', 'Mean period', 'Fraction of locally unvoiced frames', 'Number of voice breaks', 'Degree of voice breaks', 'Jitter (ppq5)', 'Shimmer (apq5)', 'Median Pitch']
#
#
# Added columns to the dataset are: Jitter (ppq5) Shimmer (apq5) Median Pitch
#
#
# ---------Standard Scaled---------
#
#
# Accuracy for training set -> 0.861969111969112
# Accuracy for test set -> 0.6875
# [[72 34]
#  [31 71]]
# Accuracy: 66.30 %
# Standard Deviation: 4.44 %
#
#
# ---------MinMax Scaled---------
#
#
# Accuracy for training set -> 0.861969111969112
# Accuracy for test set -> 0.6875
# [[72 34]
#  [31 71]]
# Accuracy: 66.42 %
# Standard Deviation: 4.42 %
#
#
# ['AC', 'NDH', 'HTM', 'Minimum pitch', 'Maximum pitch', 'Number of pulses', 'Number of periods', 'Mean period', 'Fraction of locally unvoiced frames', 'Number of voice breaks', 'Degree of voice breaks', 'Jitter (ppq5)', 'Shimmer (apq5)', 'Mean Pitch']
#
#
# Added columns to the dataset are: Jitter (ppq5) Shimmer (apq5) Mean Pitch
#
#
# ---------Standard Scaled---------
#
#
# Accuracy for training set -> 0.8552123552123552
# Accuracy for test set -> 0.6730769230769231
# [[68 38]
#  [30 72]]
# Accuracy: 66.90 %
# Standard Deviation: 5.37 %
#
#
# ---------MinMax Scaled---------
#
#
# Accuracy for training set -> 0.8552123552123552
# Accuracy for test set -> 0.6730769230769231
# [[68 38]
#  [30 72]]
# Accuracy: 66.90 %
# Standard Deviation: 5.37 %
#
#
# ['AC', 'NDH', 'HTM', 'Minimum pitch', 'Maximum pitch', 'Number of pulses', 'Number of periods', 'Mean period', 'Fraction of locally unvoiced frames', 'Number of voice breaks', 'Degree of voice breaks', 'Jitter (ppq5)', 'Shimmer (apq11)', 'Median Pitch']
#
#
# Added columns to the dataset are: Jitter (ppq5) Shimmer (apq11) Median Pitch
#
#
# ---------Standard Scaled---------
#
#
# Accuracy for training set -> 0.862934362934363
# Accuracy for test set -> 0.6875
# [[70 36]
#  [29 73]]
# Accuracy: 67.38 %
# Standard Deviation: 4.70 %
#
#
# ---------MinMax Scaled---------
#
#
# Accuracy for training set -> 0.862934362934363
# Accuracy for test set -> 0.6875
# [[70 36]
#  [29 73]]
# Accuracy: 67.38 %
# Standard Deviation: 4.70 %
#
#
# ['AC', 'NDH', 'HTM', 'Minimum pitch', 'Maximum pitch', 'Number of pulses', 'Number of periods', 'Mean period', 'Fraction of locally unvoiced frames', 'Number of voice breaks', 'Degree of voice breaks', 'Jitter (ppq5)', 'Shimmer (apq11)', 'Mean Pitch']
#
#
# Added columns to the dataset are: Jitter (ppq5) Shimmer (apq11) Mean Pitch
#
#
# ---------Standard Scaled---------
#
#
# Accuracy for training set -> 0.862934362934363
# Accuracy for test set -> 0.6971153846153846
# [[68 38]
#  [25 77]]
# Accuracy: 66.66 %
# Standard Deviation: 4.59 %
#
#
# ---------MinMax Scaled---------
#
#
# Accuracy for training set -> 0.862934362934363
# Accuracy for test set -> 0.6971153846153846
# [[68 38]
#  [25 77]]
# Accuracy: 66.66 %
# Standard Deviation: 4.59 %
#
#
# ['AC', 'NDH', 'HTM', 'Minimum pitch', 'Maximum pitch', 'Number of pulses', 'Number of periods', 'Mean period', 'Fraction of locally unvoiced frames', 'Number of voice breaks', 'Degree of voice breaks', 'Jitter (ppq5)', 'Shimmer (dda)', 'Median Pitch']
#
#
# Added columns to the dataset are: Jitter (ppq5) Shimmer (dda) Median Pitch
#
#
# ---------Standard Scaled---------
# Accuracy for training set -> 0.8571428571428571
# Accuracy for test set -> 0.6778846153846154
# [[67 39]
#  [28 74]]
# Accuracy: 67.01 %
# Standard Deviation: 6.09 %
#
#
# ---------MinMax Scaled---------
#
#
# Accuracy for training set -> 0.8571428571428571
# Accuracy for test set -> 0.6778846153846154
# [[67 39]
#  [28 74]]
# Accuracy: 67.01 %
# Standard Deviation: 6.09 %
#
#
# ['AC', 'NDH', 'HTM', 'Minimum pitch', 'Maximum pitch', 'Number of pulses', 'Number of periods', 'Mean period', 'Fraction of locally unvoiced frames', 'Number of voice breaks', 'Degree of voice breaks', 'Jitter (ppq5)', 'Shimmer (dda)', 'Mean Pitch']
#
#
# Added columns to the dataset are: Jitter (ppq5) Shimmer (dda) Mean Pitch
#
#
# ---------Standard Scaled---------
#
#
# Accuracy for training set -> 0.8581081081081081
# Accuracy for test set -> 0.6682692307692307
# [[65 41]
#  [28 74]]
# Accuracy: 66.06 %
# Standard Deviation: 4.11 %
#
#
# ---------MinMax Scaled---------
#
#
# Accuracy for training set -> 0.8581081081081081
# Accuracy for test set -> 0.6682692307692307
# [[65 41]
#  [28 74]]
# Accuracy: 66.06 %
# Standard Deviation: 4.11 %
#
#
# ['AC', 'NDH', 'HTM', 'Minimum pitch', 'Maximum pitch', 'Number of pulses', 'Number of periods', 'Mean period', 'Fraction of locally unvoiced frames', 'Number of voice breaks', 'Degree of voice breaks', 'Jitter (ddp)', 'Shimmer (local)', 'Median Pitch']
#
#
# Added columns to the dataset are: Jitter (ddp) Shimmer (local) Median Pitch
#
#
# ---------Standard Scaled---------
#
#
# Accuracy for training set -> 0.8638996138996139
# Accuracy for test set -> 0.6682692307692307
# [[65 41]
#  [28 74]]
# Accuracy: 67.86 %
# Standard Deviation: 3.82 %
#
#
# ---------MinMax Scaled---------
#
#
# Accuracy for training set -> 0.8638996138996139
# Accuracy for test set -> 0.6682692307692307
# [[65 41]
#  [28 74]]
# Accuracy: 67.86 %
# Standard Deviation: 3.82 %
#
#
# ['AC', 'NDH', 'HTM', 'Minimum pitch', 'Maximum pitch', 'Number of pulses', 'Number of periods', 'Mean period', 'Fraction of locally unvoiced frames', 'Number of voice breaks', 'Degree of voice breaks', 'Jitter (ddp)', 'Shimmer (local)', 'Mean Pitch']
#
#
# Added columns to the dataset are: Jitter (ddp) Shimmer (local) Mean Pitch
#
#
# ---------Standard Scaled---------
#
#
# Accuracy for training set -> 0.861003861003861
# Accuracy for test set -> 0.6730769230769231
# [[62 44]
#  [24 78]]
# Accuracy: 68.11 %
# Standard Deviation: 2.89 %
#
#
# ---------MinMax Scaled---------
#
#
# Accuracy for training set -> 0.861003861003861
# Accuracy for test set -> 0.6730769230769231
# [[62 44]
#  [24 78]]
# Accuracy: 67.99 %
# Standard Deviation: 2.95 %
#
#
# ['AC', 'NDH', 'HTM', 'Minimum pitch', 'Maximum pitch', 'Number of pulses', 'Number of periods', 'Mean period', 'Fraction of locally unvoiced frames', 'Number of voice breaks', 'Degree of voice breaks', 'Jitter (ddp)', 'Shimmer (local, db)', 'Median Pitch']
#
#
# Added columns to the dataset are: Jitter (ddp) Shimmer (local, db) Median Pitch
#
#
# ---------Standard Scaled---------
#
#
# Accuracy for training set -> 0.8706563706563707
# Accuracy for test set -> 0.6778846153846154
# [[67 39]
#  [28 74]]
# Accuracy: 67.99 %
# Standard Deviation: 4.05 %
#
#
# ---------MinMax Scaled---------
#
#
# Accuracy for training set -> 0.8706563706563707
# Accuracy for test set -> 0.6778846153846154
# [[67 39]
#  [28 74]]
# Accuracy: 67.99 %
# Standard Deviation: 4.05 %
#
#
# ['AC', 'NDH', 'HTM', 'Minimum pitch', 'Maximum pitch', 'Number of pulses', 'Number of periods', 'Mean period', 'Fraction of locally unvoiced frames', 'Number of voice breaks', 'Degree of voice breaks', 'Jitter (ddp)', 'Shimmer (local, db)', 'Mean Pitch']
#
#
# Added columns to the dataset are: Jitter (ddp) Shimmer (local, db) Mean Pitch
#
#
# ---------Standard Scaled---------
#
#
# Accuracy for training set -> 0.861003861003861
# Accuracy for test set -> 0.6778846153846154
# [[67 39]
#  [28 74]]
# Accuracy: 66.54 %
# Standard Deviation: 3.85 %
#
#
# ---------MinMax Scaled---------
#
#
# Accuracy for training set -> 0.861003861003861
# Accuracy for test set -> 0.6778846153846154
# [[67 39]
#  [28 74]]
# Accuracy: 66.54 %
# Standard Deviation: 3.85 %
#
#
# ['AC', 'NDH', 'HTM', 'Minimum pitch', 'Maximum pitch', 'Number of pulses', 'Number of periods', 'Mean period', 'Fraction of locally unvoiced frames', 'Number of voice breaks', 'Degree of voice breaks', 'Jitter (ddp)', 'Shimmer (apq3)', 'Median Pitch']
#
#
# Added columns to the dataset are: Jitter (ddp) Shimmer (apq3) Median Pitch
#
#
# ---------Standard Scaled---------
#
#
# Accuracy for training set -> 0.8513513513513513
# Accuracy for test set -> 0.6586538461538461
# [[64 42]
#  [29 73]]
# Accuracy: 66.06 %
# Standard Deviation: 4.71 %
#
#
# ---------MinMax Scaled---------
#
#
# Accuracy for training set -> 0.8513513513513513
# Accuracy for test set -> 0.6586538461538461
# [[64 42]
#  [29 73]]
# Accuracy: 66.06 %
# Standard Deviation: 4.71 %
#
#
# ['AC', 'NDH', 'HTM', 'Minimum pitch', 'Maximum pitch', 'Number of pulses', 'Number of periods', 'Mean period', 'Fraction of locally unvoiced frames', 'Number of voice breaks', 'Degree of voice breaks', 'Jitter (ddp)', 'Shimmer (apq3)', 'Mean Pitch']
#
#
# Added columns to the dataset are: Jitter (ddp) Shimmer (apq3) Mean Pitch
#
#
# ---------Standard Scaled---------
#
#
# Accuracy for training set -> 0.8445945945945946
# Accuracy for test set -> 0.6490384615384616
# [[64 42]
#  [31 71]]
# Accuracy: 64.60 %
# Standard Deviation: 3.91 %
#
#
# ---------MinMax Scaled---------
#
#
# Accuracy for training set -> 0.8445945945945946
# Accuracy for test set -> 0.6490384615384616
# [[64 42]
#  [31 71]]
# Accuracy: 64.60 %
# Standard Deviation: 3.91 %
#
#
# ['AC', 'NDH', 'HTM', 'Minimum pitch', 'Maximum pitch', 'Number of pulses', 'Number of periods', 'Mean period', 'Fraction of locally unvoiced frames', 'Number of voice breaks', 'Degree of voice breaks', 'Jitter (ddp)', 'Shimmer (apq5)', 'Median Pitch']
#
#
# Added columns to the dataset are: Jitter (ddp) Shimmer (apq5) Median Pitch
#
#
# ---------Standard Scaled---------
#
#
# Accuracy for training set -> 0.8745173745173745
# Accuracy for test set -> 0.6682692307692307
# [[68 38]
#  [31 71]]
# Accuracy: 67.51 %
# Standard Deviation: 5.05 %
#
#
# ---------MinMax Scaled---------
#
#
# Accuracy for training set -> 0.8745173745173745
# Accuracy for test set -> 0.6682692307692307
# [[68 38]
#  [31 71]]
# Accuracy: 67.51 %
# Standard Deviation: 5.05 %
#
#
# ['AC', 'NDH', 'HTM', 'Minimum pitch', 'Maximum pitch', 'Number of pulses', 'Number of periods', 'Mean period', 'Fraction of locally unvoiced frames', 'Number of voice breaks', 'Degree of voice breaks', 'Jitter (ddp)', 'Shimmer (apq5)', 'Mean Pitch']
#
#
# Added columns to the dataset are: Jitter (ddp) Shimmer (apq5) Mean Pitch
#
#
# ---------Standard Scaled---------
#
#
# Accuracy for training set -> 0.8716216216216216
# Accuracy for test set -> 0.6875
# [[69 37]
#  [28 74]]
# Accuracy: 67.03 %
# Standard Deviation: 4.60 %
#
#
# ---------MinMax Scaled---------
#
#
# Accuracy for training set -> 0.8716216216216216
# Accuracy for test set -> 0.6875
# [[69 37]
#  [28 74]]
# Accuracy: 67.03 %
# Standard Deviation: 4.60 %
#
#
# ['AC', 'NDH', 'HTM', 'Minimum pitch', 'Maximum pitch', 'Number of pulses', 'Number of periods', 'Mean period', 'Fraction of locally unvoiced frames', 'Number of voice breaks', 'Degree of voice breaks', 'Jitter (ddp)', 'Shimmer (apq11)', 'Median Pitch']
#
#
# Added columns to the dataset are: Jitter (ddp) Shimmer (apq11) Median Pitch
#
#
# ---------Standard Scaled---------
#
#
# Accuracy for training set -> 0.8812741312741312
# Accuracy for test set -> 0.7067307692307693
# [[72 34]
#  [27 75]]
# Accuracy: 67.26 %
# Standard Deviation: 3.18 %
#
#
# ---------MinMax Scaled---------
#
#
# Accuracy for training set -> 0.8812741312741312
# Accuracy for test set -> 0.7067307692307693
# [[72 34]
#  [27 75]]
# Accuracy: 67.26 %
# Standard Deviation: 3.18 %
#
#
# ['AC', 'NDH', 'HTM', 'Minimum pitch', 'Maximum pitch', 'Number of pulses', 'Number of periods', 'Mean period', 'Fraction of locally unvoiced frames', 'Number of voice breaks', 'Degree of voice breaks', 'Jitter (ddp)', 'Shimmer (apq11)', 'Mean Pitch']
#
#
# Added columns to the dataset are: Jitter (ddp) Shimmer (apq11) Mean Pitch
#
#
# ---------Standard Scaled---------
#
#
# Accuracy for training set -> 0.8696911196911197
# Accuracy for test set -> 0.6875
# [[71 35]
#  [30 72]]
# Accuracy: 67.14 %
# Standard Deviation: 4.40 %
#
#
# ---------MinMax Scaled---------
#
#
# Accuracy for training set -> 0.8696911196911197
# Accuracy for test set -> 0.6875
# [[71 35]
#  [30 72]]
# Accuracy: 67.14 %
# Standard Deviation: 4.40 %
#
#
# ['AC', 'NDH', 'HTM', 'Minimum pitch', 'Maximum pitch', 'Number of pulses', 'Number of periods', 'Mean period', 'Fraction of locally unvoiced frames', 'Number of voice breaks', 'Degree of voice breaks', 'Jitter (ddp)', 'Shimmer (dda)', 'Median Pitch']
#
#
# Added columns to the dataset are: Jitter (ddp) Shimmer (dda) Median Pitch
#
#
# ---------Standard Scaled---------
# Accuracy for training set -> 0.8513513513513513
# Accuracy for test set -> 0.6586538461538461
# [[64 42]
#  [29 73]]
# Accuracy: 65.82 %
# Standard Deviation: 4.81 %
#
#
# ---------MinMax Scaled---------
#
#
# Accuracy for training set -> 0.8513513513513513
# Accuracy for test set -> 0.6586538461538461
# [[64 42]
#  [29 73]]
# Accuracy: 65.82 %
# Standard Deviation: 4.81 %
#
#
# ['AC', 'NDH', 'HTM', 'Minimum pitch', 'Maximum pitch', 'Number of pulses', 'Number of periods', 'Mean period', 'Fraction of locally unvoiced frames', 'Number of voice breaks', 'Degree of voice breaks', 'Jitter (ddp)', 'Shimmer (dda)', 'Mean Pitch']
#
#
# Added columns to the dataset are: Jitter (ddp) Shimmer (dda) Mean Pitch
#
#
# ---------Standard Scaled---------
#
#
# Accuracy for training set -> 0.8445945945945946
# Accuracy for test set -> 0.6490384615384616
# [[64 42]
#  [31 71]]
# Accuracy: 64.60 %
# Standard Deviation: 3.91 %
#
#
# ---------MinMax Scaled---------
#
#
# Accuracy for training set -> 0.8445945945945946
# Accuracy for test set -> 0.6490384615384616
# [[64 42]
#  [31 71]]
# Accuracy: 64.60 %
# Standard Deviation: 3.91 %

# %%
fixed_cols

# %%
getGBBoosting(standard_scaled_X, y)
# Out:
# Accuracy for training set -> 0.888996138996139
# Accuracy for test set -> 0.7355769230769231
# [[77 29]
#  [26 76]]
# Accuracy: 68.48 %
# Standard Deviation: 5.01 %

# %%
getGBBoosting(minmax_scaled_X, y)
# Out:
# Accuracy for training set -> 0.888996138996139
# Accuracy for test set -> 0.7355769230769231
# [[77 29]
#  [26 76]]
# Accuracy: 68.48 %
# Standard Deviation: 5.01 %
